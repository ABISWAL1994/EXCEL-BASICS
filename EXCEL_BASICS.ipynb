# %% [markdown]
#  # Excel Basics

# %% [markdown]
#      1. xplain the difference between Relative , Absolute and Mixed Cell       Referencing.
#
#        -> Relative adjusts automatically in all direction
#        -> Absolute stay fixed column & Row
#        -> Mixed locks either the row or column
#
#     2. rite a formula to calculate the total sales of Car and Bicyle only only.
#
#        -> =sum("car sales", "bicycle sales")
#
#     3. Using the data below, write a formula to calculate the average sales of items priced above 100 but less than 300.
#
#       -> =averageifs(C2:C4,B2:B4, ">100",B2:B4, "<300")

# %% [markdown]
#  # DATASET LINK ANSWER

# %% [markdown]
#          1. Count how many customer names are recorded.
#             -> 50
#
#          2. Calculate the Total Sales for each row using a formula.
#             -> =PRODUCT($E2*$F2)
#
#          3.Calculate the total sales of Notebooks in the North region only.
#             -> 58
